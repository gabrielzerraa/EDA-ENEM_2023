# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
versoes = {'Pandas':pd.__version__, 'Numpy':np.__version__, 'Seaborn':sns.__version__}
versoes
# Out:
# {'Pandas': '2.1.4', 'Numpy': '1.26.4', 'Seaborn': '0.12.2'}

# %%
with open('microdados_enem_2023\DADOS\MICRODADOS_ENEM_2023.csv') as f:
#with open('C:\Users\gabriel.bezerra\Documents\microdados_enem_2023\MICRODADOS_ENEM_2023.csv') as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='microdados_enem_2023\\DADOS\\MICRODADOS_ENEM_2023.csv' mode='r' encoding='cp1252'>

# %%
# Define o número máximo de colunas a serem exibidas
pd.set_option('display.max_columns', 80)

# Define o número de casas decimais para valores em ponto flutuante
pd.set_option('display.precision', 2)

# %%
# Comeco
comeco = datetime.datetime.now()
print(comeco)

#df = pd.read_csv('DADOS\MICRODADOS_ENEM_2023.csv', encoding='cp1252', sep=';')
df = pd.read_csv('microdados_enem_2023\DADOS\MICRODADOS_ENEM_2023.csv', encoding='cp1252', sep=';')

# Final
final = datetime.datetime.now()
print(final)

tempo = final - comeco
tempo
# Out:
# 2024-05-15 16:26:33.898851
# 2024-05-15 16:28:17.400933
# datetime.timedelta(seconds=103, microseconds=502082)

# %% [markdown]
# # Informações Básicas do Datarame

# %%
# Mostrar os primeiros dados do dataframe
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210059085136    2023               14       M                2
# 1  210059527735    2023               12       M                2
# 2  210061103945    2023                6       F                1
# 3  210060214087    2023                2       F                1
# 4  210059980948    2023                3       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1               17          1
# 1            1                 0                1               16          1
# 2            1                 1                1                0          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    TP_ENSINO  IN_TREINEIRO  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC  \
# ...

# %%
# Dimmensão do dataframe
dim = df.shape
print(f'A tabela tem {dim[0]} milhões de linhas e {dim[1]} colunas')
# Out:
# A tabela tem 3933955 milhões de linhas e 76 colunas

# %%
# Informações do dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3933955 entries, 0 to 3933954
# Data columns (total 76 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   NU_INSCRICAO            int64
#  1   NU_ANO                  int64
#  2   TP_FAIXA_ETARIA         int64
#  3   TP_SEXO                 object
#  4   TP_ESTADO_CIVIL         int64
#  5   TP_COR_RACA             int64
#  6   TP_NACIONALIDADE        int64
#  7   TP_ST_CONCLUSAO         int64
#  8   TP_ANO_CONCLUIU         int64
#  9   TP_ESCOLA               int64
#  10  TP_ENSINO               float64
#  11  IN_TREINEIRO            int64
#  12  CO_MUNICIPIO_ESC        float64
#  13  NO_MUNICIPIO_ESC        object
#  14  CO_UF_ESC               float64
#  15  SG_UF_ESC               object
#  16  TP_DEPENDENCIA_ADM_ESC  float64
#  17  TP_LOCALIZACAO_ESC      float64
#  18  TP_SIT_FUNC_ESC         float64
#  19  CO_MUNICIPIO_PROVA      int64
#  20  NO_MUNICIPIO_PROVA      object
# ...

# %%
# Valores únicos do dataframe
df.nunique().reset_index()
# Out:
#               index        0
# 0      NU_INSCRICAO  3933955
# 1            NU_ANO        1
# 2   TP_FAIXA_ETARIA       20
# 3           TP_SEXO        2
# 4   TP_ESTADO_CIVIL        5
# ..              ...      ...
# 71             Q021        2
# 72             Q022        5
# 73             Q023        2
# 74             Q024        5
# 75             Q025        2
#
# [76 rows x 2 columns]

# %%
# Valores Duplicados
df.duplicated().sum().sum()
# Out:
# 0

# %% [markdown]
# # Verificando Dados Nuloss

# %% [markdown]
# ## Identificando Valores Ausentes

# %% [markdown]
# ### Percentual dos Valores Ausentes

# %%
# Total de Valores Ausentes
total_ausentes = df.isnull().sum().sum()

# Total de Células
total_celulas = np.product(df.shape)

# Percentual dos valores ausentes
percentual_ausentes = total_ausentes/total_celulas * 100

# Print
print(f'Porcentagem dos dados ausentes: {percentual_ausentes:.2f}%')
# Out:
# Porcentagem dos dados ausentes: 16.73%

# %% [markdown]
# ### Percentual de Valores Ausentes por Colunas

# %%
# Total de Valores Ausentes
total_ausentes = df.isnull().sum() 

# Porcentagem de valores ausentes em cada coluna
percentual_por_coluna = total_ausentes / len(df) * 100

# Type de cada coluna
type_coluna = df.dtypes

# Criar um dataframe com os resultados
df_dados_linhas_ausentes = pd.DataFrame({
    'Valores Ausentes':total_ausentes,
    'Percentual':percentual_por_coluna,
    'Type':type_coluna
}).sort_values('Percentual', ascending=False)

df_dados_linhas_ausentes
# Out:
#                         Valores Ausentes  Percentual     Type
# TP_LOCALIZACAO_ESC               2975449       75.64  float64
# CO_UF_ESC                        2975449       75.64  float64
# TP_SIT_FUNC_ESC                  2975449       75.64  float64
# TP_DEPENDENCIA_ADM_ESC           2975449       75.64  float64
# SG_UF_ESC                        2975449       75.64   object
# ...                                  ...         ...      ...
# TP_PRESENCA_LC                         0        0.00    int64
# TP_PRESENCA_MT                         0        0.00    int64
# NU_ANO                                 0        0.00    int64
# TP_LINGUA                              0        0.00    int64
# Q025                                   0        0.00   object
#
# [76 rows x 3 columns]

# %% [markdown]
# ## Apagar colunas 27 a 76
# Apagar as colunas para deixar o dataset mais leve, desssa forma podemos visuailizar os dados com mais facilidade.

# %%
colunas = df.iloc[:, 27:].columns
df = df.drop(colunas, axis=1)
df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210059085136    2023               14       M                2
# 1  210059527735    2023               12       M                2
# 2  210061103945    2023                6       F                1
# 3  210060214087    2023                2       F                1
# 4  210059980948    2023                3       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1               17          1
# 1            1                 0                1               16          1
# 2            1                 1                1                0          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    TP_ENSINO  IN_TREINEIRO  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  CO_UF_ESC  \
# ...

# %% [markdown]
# # Visualização de Dados

# %%
plt.figure(figsize=(7,4))

ax = sns.countplot(df, x="TP_SEXO",  palette='Paired')

plt.show()

# %%
plt.figure(figsize=(7,4))

ax = sns.countplot(df, x="TP_SEXO",  palette='Paired')

ax.set_title('Sexos', loc='left', fontsize=20)
ax.set_xlabel('Sexo', fontsize=15)
ax.set_ylabel('Contagem', fontsize=15)


# Remover Gird
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)




plt.show()

# %%
sns.countplot(df, x="TP_FAIXA_ETARIA")
# Out:
# <Axes: xlabel='TP_FAIXA_ETARIA', ylabel='count'>

# %%
sns.countplot(df, x="TP_ESTADO_CIVIL")
# Out:
# <Axes: xlabel='TP_ESTADO_CIVIL', ylabel='count'>

# %%
sns.countplot(df, x="TP_NACIONALIDADE")
# Out:
# <Axes: xlabel='TP_NACIONALIDADE', ylabel='count'>
